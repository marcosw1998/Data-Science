# %%
import numpy as np
import pandas as pd
houses=pd.read_csv("https://raw.githubusercontent.com/if1015-datascience/material/gh-pages/data/recife.csv",encoding = "ISO-8859-1")

# %%
houses.head()
# Out:
#     price  latitude  longitude  bedrooms  ...  district    city       state   type
# 0    1500 -8.059791 -34.889619       4.0  ...    Recife  Recife  Pernambuco  apart
# 1  330000 -8.029595 -34.900372       3.0  ...    Recife  Recife  Pernambuco  apart
# 2  255000 -8.037247 -34.890986       2.0  ...    Recife  Recife  Pernambuco  apart
# 3  380000 -8.047562 -34.876964       3.0  ...    Recife  Recife  Pernambuco  apart
# 4  300000 -8.053580 -34.908733       3.0  ...    Recife  Recife  Pernambuco  apart
#
# [5 rows x 13 columns]

# %% [markdown]
# ## Exercício 1: Defina se um imóvel está à venda ou para locação a partir do preço

# %%
houses['log_price'] = houses['price'].apply(np.log10)

# %%
houses[houses['log_price'] > 0]['log_price'].hist()

# %%
houses['operation'] = 'sell'

# %%
houses.loc[(houses['price'] > 100) & (houses['price'] < 30000),'operation'] = 'rent'

# %%
houses.head()
# Out:
#     price  latitude  longitude  bedrooms  area  pkspaces  bathrooms  ensuites  \
# 0    1500 -8.059791 -34.889619       4.0  37.0       3.0        3.0       NaN
# 1  330000 -8.029595 -34.900372       3.0  86.0       1.0        3.0       1.0
# 2  255000 -8.037247 -34.890986       2.0  82.0       1.0        2.0       NaN
# 3  380000 -8.047562 -34.876964       3.0  95.0       2.0        3.0       1.0
# 4  300000 -8.053580 -34.908733       3.0  97.0       1.0        3.0       1.0
#
#          suburb district    city       state   type  log_price operation
# 0     Boa Vista   Recife  Recife  Pernambuco  apart   3.176091      rent
# 1   Tamarineira   Recife  Recife  Pernambuco  apart   5.518514      sell
# 2  Encruzilhada   Recife  Recife  Pernambuco  apart   5.406540      sell
# 3   Santo Amaro   Recife  Recife  Pernambuco  apart   5.579784      sell
# 4      Madalena   Recife  Recife  Pernambuco  apart   5.477121      sell

# %%
price_square_meter = houses['price']/houses['area']

# %%
houses.groupby('suburb').price_square_meter.agg(['mean', 'median'])
# Out:
#                               mean       median
# suburb
# Aflitos                4127.003231  4074.074074
# Apipucos               4953.378876  4317.180617
# Areias                 2317.073171  2317.073171
# Arruda                 2830.172661  1950.000000
# Boa Viagem             2720.107894    39.655172
# Boa Vista              1178.620273    14.285714
# Campo Grande           3526.083697  3730.158730
# Casa Amarela           4222.602865  5217.213115
# Casa Forte             5575.571408  6097.560976
# CaxangÌÁ               3445.972509  1985.837607
# Cidade UniversitÌÁria    40.412541    20.792079
# Coelhos                4666.666667  4666.666667
# Cohab                  1933.333333  1933.333333
# Cordeiro               3168.454924  3566.416040
# Curado                   15.000000    15.000000
# Derby                  5171.815543  2574.517391
# Dois IrmÌ£os              3.986667     3.986667
# Encruzilhada           4540.722605  5277.777778
# Engenho do Meio        5790.620197  2586.206897
# Espinheiro             4383.822196  4000.000000
# EstÌ¢ncia                12.765957    12.765957
# FundÌ£o                3920.280333  3920.280333
# GraÌ¤as                3046.301765  3392.330383
# HipÌ_dromo             2502.343750  1666.666667
# Ibura                  5990.463333  6000.000000
# Ilha do Retiro         4046.988383  6069.261752
# Imbiribeira            6755.103379  3690.611626
# Ipsep                  2317.159314  2527.380952
# Iputinga                569.449338    17.647059
# Jaqueira               5589.679451  5571.428571
# Jardim SÌ£o Paulo         6.002158     0.003597
# Madalena               4431.895955  4714.285714
# Mangabeira             4138.295095  4138.295095
# Monteiro               5092.269264  5937.500000
# Mustardinha              12.500000    12.500000
# Paissandu                 9.259259     9.259259
# Parnamirim             4064.927927  4500.000000
# Pau-Ferro              2395.826190  2395.826190
# Pina                   5299.374715  5900.621118
# Ponto de Parada        2988.160287  2260.869565
# Porto da Madeira       2500.000000  2500.000000
# PoÌ¤o                  5788.837288  6466.666667
# Prado                  4196.328998  4666.666667
# Rosarinho              3590.555040  4717.857143
# San Martin             3359.787765  4411.764706
# Santana                4908.326971  4942.965779
# Santo Amaro            4231.006843  4166.666667
# Santo AntÌ«nio         4000.000000  4000.000000
# Soledade               8922.708986  5695.652174
# SÌ£o JosÌ©             1667.983122  1667.983122
# Tamarineira            4938.819400  5138.888889
# TejipiÌ_                360.974006    19.791667
# Torre                  4245.317082  4205.607477
# TorreÌ£o               4826.267203  5238.095238
# TorrÌµes               1365.000000  1365.000000
# Vasco da Gama          3125.000000  3125.000000
# VÌÁrzea                1698.266850    18.461538
# Zumbi                    16.388889    16.388889

# %% [markdown]
# ## Exercício 2: Calcule a média e mediana de venda do metro quadrado por bairros

# %%
houses['price_square_meter'] = houses['price']/houses['area']

# %%
houses[houses['operation']=='sell'].groupby(['suburb'])['price_square_meter'].mean()
# Out:
# suburb
# Aflitos              5057.981293
# Apipucos             4953.378876
# Areias               2317.073171
# Arruda               3599.960047
# Boa Viagem           5784.767213
# Boa Vista            3499.194950
# Campo Grande         4648.761296
# Casa Amarela         5351.374665
# Casa Forte           6183.445243
# CaxangÌÁ             4587.357285
# Coelhos              4666.666667
# Cohab                1933.333333
# Cordeiro             4083.564554
# Derby                9043.387168
# Encruzilhada         5052.220649
# Engenho do Meio      9641.890805
# Espinheiro           5231.928476
# FundÌ£o              3920.280333
# GraÌ¤as              4350.551441
# HipÌ_dromo           2502.343750
# Ibura                5990.463333
# Ilha do Retiro       6055.816062
# Imbiribeira          9902.509394
# Ipsep                2777.982481
# Iputinga             1770.728716
# Jaqueira             6742.418062
# Jardim SÌ£o Paulo       0.003597
# Madalena             5794.175868
# Mangabeira           4138.295095
# Monteiro             6544.807869
# Parnamirim           5261.133661
# Pau-Ferro            2395.826190
# Pina                 7330.712373
# Ponto de Parada      5217.510616
# Porto da Madeira     2500.000000
# PoÌ¤o                6291.697998
# Prado                5181.694309
# Rosarinho            5581.350132
# San Martin           4475.841052
# Santana              6863.182567
# Santo Amaro          4989.380697
# Santo AntÌ«nio       4000.000000
# Soledade             9607.917369
# SÌ£o JosÌ©           1667.983122
# Tamarineira          5584.412500
# TejipiÌ_             1043.338684
# Torre                5631.042611
# TorreÌ£o             4826.267203
# TorrÌµes             2720.000000
# Vasco da Gama        3125.000000
# VÌÁrzea              4225.103022
# Name: price_square_meter, dtype: float64

# %%
houses[houses['operation']=='sell'].groupby(['suburb']).agg(['mean','median'])['price_square_meter']
# Out:
#                           mean       median
# suburb
# Aflitos            5057.981293  4897.959184
# Apipucos           4953.378876  4317.180617
# Areias             2317.073171  2317.073171
# Arruda             3599.960047  4000.000000
# Boa Viagem         5784.767213  5351.562500
# Boa Vista          3499.194950  3240.384615
# Campo Grande       4648.761296  4130.434783
# Casa Amarela       5351.374665  5806.451613
# Casa Forte         6183.445243  6272.727273
# CaxangÌÁ           4587.357285  2915.973443
# Coelhos            4666.666667  4666.666667
# Cohab              1933.333333  1933.333333
# Cordeiro           4083.564554  4133.333333
# Derby              9043.387168  4457.603875
# Encruzilhada       5052.220649  5409.836066
# Engenho do Meio    9641.890805  4980.172414
# Espinheiro         5231.928476  4104.477612
# FundÌ£o            3920.280333  3920.280333
# GraÌ¤as            4350.551441  4082.491582
# HipÌ_dromo         2502.343750  1666.666667
# Ibura              5990.463333  6000.000000
# Ilha do Retiro     6055.816062  6071.428571
# Imbiribeira        9902.509394  4782.608696
# Ipsep              2777.982481  3150.000000
# Iputinga           1770.728716  1799.090909
# Jaqueira           6742.418062  6842.105263
# Jardim SÌ£o Paulo     0.003597     0.003597
# Madalena           5794.175868  5376.344086
# Mangabeira         4138.295095  4138.295095
# Monteiro           6544.807869  5957.142857
# Parnamirim         5261.133661  5217.391304
# Pau-Ferro          2395.826190  2395.826190
# Pina               7330.712373  7875.000000
# Ponto de Parada    5217.510616  5819.737964
# Porto da Madeira   2500.000000  2500.000000
# PoÌ¤o              6291.697998  6730.769231
# Prado              5181.694309  4883.720930
# Rosarinho          5581.350132  6428.999505
# San Martin         4475.841052  4815.643649
# Santana            6863.182567  5853.658537
# Santo Amaro        4989.380697  5333.333333
# Santo AntÌ«nio     4000.000000  4000.000000
# Soledade           9607.917369  6000.000000
# SÌ£o JosÌ©         1667.983122  1667.983122
# Tamarineira        5584.412500  5504.237288
# TejipiÌ_           1043.338684  1043.338684
# Torre              5631.042611  5228.558941
# TorreÌ£o           4826.267203  5238.095238
# TorrÌµes           2720.000000  2720.000000
# Vasco da Gama      3125.000000  3125.000000
# VÌÁrzea            4225.103022  4225.103022

# %% [markdown]
# ## Exercício 3: Plot as medianas do valor de venda por metro quadrado para cada bairro e análise algum bairro que vc ache que tenha um problema nos dados a partir dos quartis, boxplot, describe etc.

# %%
houses[houses['operation']=='sell'].groupby(['suburb'])['price_square_meter'].median().sort_values(ascending=False).plot.bar()

# %%
houses[(houses['suburb'] == 'Soledade') & (houses['operation']=='sell')].describe()
# Out:
#               price   latitude  longitude   bedrooms         area   pkspaces  \
# count  1.300000e+01  13.000000  13.000000  13.000000    13.000000  10.000000
# mean   1.193943e+06  -8.055494 -34.893257   3.230769   213.623846   1.700000
# std    1.868665e+06   0.000952   0.002665   1.012739   442.405253   0.823273
# min    2.500000e+05  -8.056280 -34.895347   1.000000    40.110000   0.000000
# 25%    3.650000e+05  -8.055979 -34.895347   3.000000    51.000000   1.250000
# 50%    6.200000e+05  -8.055979 -34.895347   3.000000   115.000000   2.000000
# 75%    6.900000e+05  -8.054936 -34.890077   4.000000   115.000000   2.000000
# max    7.000000e+06  -8.052734 -34.889466   5.000000  1682.000000   3.000000
#
#        bathrooms  ensuites  log_price  price_square_meter
# count  11.000000       7.0  13.000000           13.000000
# mean    3.090909       1.0   5.828279         9607.917369
# std     0.301511       0.0   0.410753        14132.119159
# min     3.000000       1.0   5.397940         1948.694030
# 25%     3.000000       1.0   5.562293         5391.304348
# 50%     3.000000       1.0   5.792392         6000.000000
# 75%     3.000000       1.0   5.838849         6606.831214
# max     4.000000       1.0   6.845098        56039.215686

# %%
houses[(houses['suburb'] == 'Soledade') & (houses['operation']=='sell')].boxplot(column=['price'])

# %%
houses[(houses['suburb'] == 'Soledade') & (houses['operation']=='sell')]
# Out:
#         price  latitude  longitude  bedrooms     area  pkspaces  bathrooms  \
# 179    365000 -8.054936 -34.889466       4.0    51.00       NaN        3.0
# 182    690000 -8.055979 -34.895347       3.0   115.00       2.0        3.0
# 231    620000 -8.055979 -34.895347       3.0   115.00       2.0        3.0
# 400   2858000 -8.054936 -34.889466       4.0    51.00       NaN        3.0
# 476    620000 -8.055979 -34.895347       3.0   115.00       2.0        3.0
# 618    690000 -8.055979 -34.895347       3.0   115.00       2.0        3.0
# 628    592139 -8.054936 -34.889466       4.0    51.00       NaN        3.0
# 752    690000 -8.055979 -34.895347       3.0   115.00       2.0        3.0
# 788    620000 -8.055979 -34.895347       3.0   115.00       2.0        3.0
# 862    261125 -8.055979 -34.895347       4.0   134.00       3.0        3.0
# 1044   250000 -8.052734 -34.890077       2.0    78.00       1.0        NaN
# 1067   265000 -8.056280 -34.894063       1.0    40.11       1.0        NaN
# 1364  7000000 -8.055745 -34.892368       5.0  1682.00       0.0        4.0
#
#       ensuites    suburb district    city       state   type  log_price  \
# 179        NaN  Soledade   Recife  Recife  Pernambuco  apart   5.562293
# 182        1.0  Soledade   Recife  Recife  Pernambuco  apart   5.838849
# 231        1.0  Soledade   Recife  Recife  Pernambuco  apart   5.792392
# 400        NaN  Soledade   Recife  Recife  Pernambuco  apart   6.456062
# 476        1.0  Soledade   Recife  Recife  Pernambuco  apart   5.792392
# 618        1.0  Soledade   Recife  Recife  Pernambuco  apart   5.838849
# 628        NaN  Soledade   Recife  Recife  Pernambuco  apart   5.772424
# 752        1.0  Soledade   Recife  Recife  Pernambuco  apart   5.838849
# 788        1.0  Soledade   Recife  Recife  Pernambuco  apart   5.792392
# 862        1.0  Soledade   Recife  Recife  Pernambuco  apart   5.416848
# 1044       NaN  Soledade   Recife  Recife  Pernambuco  apart   5.397940
# 1067       NaN  Soledade   Recife  Recife  Pernambuco  apart   5.423246
# 1364       NaN  Soledade   Recife  Recife  Pernambuco  house   6.845098
#
#      operation  price_square_meter
# 179       sell         7156.862745
# 182       sell         6000.000000
# 231       sell         5391.304348
# 400       sell        56039.215686
# 476       sell         5391.304348
# 618       sell         6000.000000
# 628       sell        11610.568627
# 752       sell         6000.000000
# 788       sell         5391.304348
# 862       sell         1948.694030
# 1044      sell         3205.128205
# 1067      sell         6606.831214
# 1364      sell         4161.712247

# %% [markdown]
# # Resposta Ex. 3

# %%
houses[houses['operation']=='sell'].groupby(['suburb'])['price_square_meter'].median().sort_values(ascending=False).plot.bar(figsize=(20,10))

# %%
houses[houses['suburb']=='Ibura'].describe()
# Out:
#                price  latitude  ...  log_price  price_square_meter
# count       3.000000  3.000000  ...   3.000000            3.000000
# mean   699046.333333 -8.120480  ...   5.836141         5990.463333
# std    174149.744302  0.017881  ...   0.102386           64.833202
# min    592139.000000 -8.141128  ...   5.772424         5921.390000
# 25%    598569.500000 -8.125642  ...   5.777090         5960.695000
# 50%    605000.000000 -8.110156  ...   5.781755         6000.000000
# 75%    752500.000000 -8.110156  ...   5.867999         6025.000000
# max    900000.000000 -8.110156  ...   5.954243         6050.000000
#
# [8 rows x 10 columns]
